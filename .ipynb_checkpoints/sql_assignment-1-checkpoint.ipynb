# %% [markdown]
# ### <center>SQL Assignment 1</center>

# %%
import pandas as pd
import sqlalchemy
import numpy as np
import sqlite3 as db

# %%
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q,globals())

# %%
pysqldf
# Out:
# <function __main__.<lambda>(q)>

# %%
columns_name =("age","workclass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hors_per_week","native_country","label")

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', names=columns_name )

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hors_per_week  native_country   label
# 0          2174             0             40   United-States   <=50K
# ...

# %%
conn = db.connect('sqldb.db')
c = conn.cursor()

# %%
df.to_sql("sqldb", conn, if_exists="append")

# %%
a = pd.read_sql("SELECT * FROM sqldb LIMIT 10;",conn)

# %%
a
# Out:
#    index  age          workclass  fnlwgt   education  education_num  \
# 0      0   39          State-gov   77516   Bachelors             13
# 1      1   50   Self-emp-not-inc   83311   Bachelors             13
# 2      2   38            Private  215646     HS-grad              9
# 3      3   53            Private  234721        11th              7
# 4      4   28            Private  338409   Bachelors             13
# 5      5   37            Private  284582     Masters             14
# 6      6   49            Private  160187         9th              5
# 7      7   52   Self-emp-not-inc  209642     HS-grad              9
# 8      8   31            Private   45781     Masters             14
# 9      9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
pysqldf("SELECT * FROM df LIMIT 10;")
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# ### 2

# %%
q = """SELECT avg(hors_per_week), sex, workclass
        FROM df
        WHERE workclass like '%vate%' and sex=' Male'
        GROUP BY workclass,sex;
    """

# %%
pysqldf(q)
# Out:
#    avg(hors_per_week)    sex workclass
# 0           42.221226   Male   Private

# %%
print(df.query("sex == ' Male' & workclass == ' Private'").groupby(["workclass","sex"])["hors_per_week"].mean())
# Out:
# workclass  sex
#  Private    Male    42.221226
# Name: hors_per_week, dtype: float64

# %%
q = """
    SELECT education,count(*)
    FROM df 
    GROUP BY education"""

# %%
pysqldf(q)
# Out:
#         education  count(*)
# 0            10th       933
# 1            11th      1175
# 2            12th       433
# 3         1st-4th       168
# 4         5th-6th       333
# 5         7th-8th       646
# 6             9th       514
# 7      Assoc-acdm      1067
# 8       Assoc-voc      1382
# 9       Bachelors      5355
# 10      Doctorate       413
# 11        HS-grad     10501
# 12        Masters      1723
# 13      Preschool        51
# 14    Prof-school       576
# 15   Some-college      7291

# %%
q = """
    SELECT occupation,count(*)
    FROM df 
    GROUP BY occupation"""

# %%
pysqldf(q)
# Out:
#             occupation  count(*)
# 0                    ?      1843
# 1         Adm-clerical      3770
# 2         Armed-Forces         9
# 3         Craft-repair      4099
# 4      Exec-managerial      4066
# 5      Farming-fishing       994
# 6    Handlers-cleaners      1370
# 7    Machine-op-inspct      2002
# 8        Other-service      3295
# 9      Priv-house-serv       149
# 10      Prof-specialty      4140
# 11     Protective-serv       649
# 12               Sales      3650
# 13        Tech-support       928
# 14    Transport-moving      1597

# %% [markdown]
# ### 3

# %%
q = """
    SELECT relationship,count(*)
    FROM df 
    GROUP BY relationship"""

# %%
pysqldf(q)
# Out:
#       relationship  count(*)
# 0          Husband     13193
# 1    Not-in-family      8305
# 2   Other-relative       981
# 3        Own-child      5068
# 4        Unmarried      3446
# 5             Wife      1568

# %% [markdown]
# ### 4 Are there any people who are married, working in private sector and having a masters degree

# %%
q = """
    SELECT *
    FROM df
    WHERE marital_status LIKE  " Married%" and workclass = ' Private' and education =' Masters' ;"""

# %%
pysqldf(q)
# Out:
#      age workclass  fnlwgt education  education_num          marital_status  \
# 0     37   Private  284582   Masters             14      Married-civ-spouse
# 1     33   Private  202051   Masters             14      Married-civ-spouse
# 2     76   Private  124191   Masters             14      Married-civ-spouse
# 3     31   Private   99928   Masters             14      Married-civ-spouse
# 4     35   Private  138992   Masters             14      Married-civ-spouse
# 5     34   Private  142897   Masters             14      Married-civ-spouse
# 6     62   Private  270092   Masters             14      Married-civ-spouse
# 7     41   Private  445382   Masters             14      Married-civ-spouse
# 8     33   Private  208405   Masters             14      Married-civ-spouse
# 9     49   Private  192776   Masters             14      Married-civ-spouse
# 10    51   Private  410114   Masters             14      Married-civ-spouse
# ...

# %% [markdown]
# ### 5.What is the average, minimum and maximum age group for people working in different sectors

# %%
q ="""
    SELECT avg(age),min(age),max(age),workclass
    FROM df
    GROUP BY workclass"""

# %%
pysqldf(q)
# Out:
#     avg(age)  min(age)  max(age)          workclass
# 0  40.960240        17        90                  ?
# 1  42.590625        17        90        Federal-gov
# 2  41.751075        17        90          Local-gov
# 3  20.571429        17        30       Never-worked
# 4  36.797585        17        90            Private
# 5  46.017025        17        84       Self-emp-inc
# 6  44.969697        17        90   Self-emp-not-inc
# 7  39.436055        17        81          State-gov
# 8  47.785714        19        72        Without-pay

# %% [markdown]
# ### 6. Calculate age distribution by country

# %%
q = """
    SELECT count(*),age,native_country
    FROM df
    GROUP BY native_country,age
    ORDER BY age, native_country"""

# %%
pysqldf(q)
# Out:
#       count(*)  age       native_country
# 0            2   17                    ?
# 1            2   17               Canada
# 2            2   17          El-Salvador
# 3            1   17              England
# 4            1   17                Haiti
# 5            1   17                India
# 6            6   17               Mexico
# 7            2   17                 Peru
# 8            1   17          Philippines
# 9            1   17               Poland
# 10           1   17          Puerto-Rico
# 11           1   17      Trinadad&Tobago
# 12         374   17        United-States
# 13           8   18                    ?
# 14           1   18             Cambodia
# 15           1   18               Canada
# 16           1   18             Columbia
# 17           1   18   Dominican-Republic
# 18           1   18              Germany
# 19           1   18             Honduras
# 20           1   18                India
# 21           1   18              Jamaica
# ...

# %% [markdown]
# ### 7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and 'capital-loss'

# %%
q = """
    SELECT capital_gain-capital_loss
    FROM df"""

# %%
df["NEt-capital-Gain"] = pysqldf(q)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hors_per_week  native_country   label  \
# ...
